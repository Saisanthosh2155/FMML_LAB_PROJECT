# %% [markdown]
# <a href="https://colab.research.google.com/github/Saisanthosh2155/FMML_LAB_PROJECT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-05 16:37:31--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   102MB/s    in 0.7s
#
# 2024-04-05 16:37:31 (102 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7747   1803.01347v1  Optimal transport (OT) distances are finding e...  stat
# 3888   1707.02711v2  Deep convolutional neural networks (CNNs) used...  stat
# 9411   1704.04478v2  In this work, we consider an extension of grap...  stat
# 28798  1707.07584v1  Foreground segmentation in video sequences is ...    cs
# 5319    1301.3568v3  We introduce a new method for training deep Bo...  stat
# ...             ...                                                ...   ...
# 13769   1410.4985v2  Evolutionary robotics is a promising approach ...    cs
# 17823  1803.04375v1  In this paper, we present a feature-based name...    cs
# 37667  1712.07752v2  Artificial Intelligence (AI), is once again in...    cs
# 22988  1712.09277v1  Classification in the dissimilarity space has ...  stat
# 22327  1602.02485v1  The problem of learning a sparse model is conc...  stat
#
#                                                    title  year  \
# 7747   Greedy stochastic algorithms for entropy-regul...  2018
# 3888   Topology Reduction in Deep Convolutional Featu...  2017
# 9411   Graphical Models: An Extension to Random Graph...  2017
# 28798  Joint Background Reconstruction and Foreground...  2017
# 5319   Joint Training Deep Boltzmann Machines for Cla...  2013
# ...                                                  ...   ...
# 13769  Evolvability signatures of generative encoding...  2014
# 17823  A Feature-Rich Vietnamese Named-Entity Recogni...  2018
# 37667  Towards an unanimous international regulatory ...  2017
# 22988  Scalable Prototype Selection by Genetic Algori...  2017
# 22327  Simultaneous Safe Screening of Features and Sa...  2016
#
#                                                 keywords
# 7747   [transport, distances, applications, computati...
# 3888   [convolutional, potentially, significant, comp...
# 9411   [extension, graphical, fundamental, multivaria...
# 28798  [foreground, segmentation, sequences, knowledg...
# 5319   [introduce, boltzmann, classification, simulta...
# ...                                                  ...
# 13769  [evolutionary, promising, autonomously, synthe...
# 17823  [recognition, vietnamese, embedding, condition...
# 37667  [artificial, intelligence, advancements, unarg...
# 22988  [classification, dissimilarity, possibility, d...
# 22327  [conceptually, interpreted, identifying, featu...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7747     [transport, distances, applications, computati...
# 3888     [convolutional, potentially, significant, comp...
# 9411     [extension, graphical, fundamental, multivaria...
# 28798    [foreground, segmentation, sequences, knowledg...
# 5319     [introduce, boltzmann, classification, simulta...
#                                ...
# 19389    [engineering, management, particular, applicat...
# 38222    [describes, quantitative, characteristics, ass...
# 7729     [individual, increased, structured, ensembles,...
# 22886    [convolutional, approaches, including, recogni...
# 17681    [responders, increasingly, information, situat...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8841 words.
# Out of those 4620 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5b83ccd9-850a-4dd1-aaaa-764b048f43db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b83ccd9-850a-4dd1-aaaa-764b048f43db")) {                    Plotly.newPlot(                        "5b83ccd9-850a-4dd1-aaaa-764b048f43db",                        [{"x":["algorithm","convergence","applications","penalization","regularized","distances","aforementioned","stochastic","practical","developed","computational","experiments","transport","algorithms","numerical","potentially","characterize","arbitrary","constraints","specifically","understanding","contained","linearity","heuristically","generalized","minimizes","bandwidth","significant","convolutional","rigorously","complexity","extraction","parameters","exponential","therefore","reduction","scattering","operating","prototype","guarantee","determine","convolutions","platforms","symmetries","capabilities","instances","representation","molecules","consistent","specified","infectious","particular","framework","distribution","functions","compactly","applicable","literature","variables","mathematical","essential","conditioned","extension","multivariate","distributions","attributes","structures","relational","including","associated","factorizations","graphical","invariances","represented","projections","independencies","undirected","fundamental","independence","furthermore","projection","assumptions","structure","complicated","projected","optimized","sophisticated","reconstruction","integrity","background","knowledge","sequences","incorporating","outperforms","foreground","reconstructed","segmentation","difficult","reconstruct","simultaneously","competitively","approximately","introduce","classification","pseudolikelihood","resulting","recurrent","interpreted","procedure","prediction","technique","approximate","variational","boltzmann","generative","approximation","inference","addressed","correcting","massively","competing","combinations","explosion","efficient","statistical","selection","combinatorial","continuous","significantly","combination","multiplicative","candidates","statistically","binarization","precision","pyramidal","dimensional","limitations","learnable","techniques","refinement","automated","detection","concerning","laborious","detecting","automatic","neurological","scenarios","encephalography","classifying","approaches","traditional","inspection","consuming","augmentation","university","performance","bottleneck","considerably","regarding","recognition","consisting","information","predictions","comparison","appearance","unfortunately","processing","advantages","crowdsourced","transform","thousands","classifier","positioning","recognize","extracting","published","integrate","demonstrate","accelerated","localization","available","predicted","maintaining","automatically","assumption","probabilities","similarly","blockmodels","approximated","statistics","gradients","appropriate","minibatches","constructed","construction","probabilistic","parameter","comparing"],"y":[828,123,454,1,33,24,9,130,130,211,273,598,8,621,95,50,45,81,117,184,189,20,8,2,73,8,8,258,382,3,228,148,262,45,158,107,6,15,22,37,68,21,35,3,50,90,365,3,90,36,3,269,570,213,223,6,50,126,126,64,64,21,71,16,128,73,159,35,260,97,3,58,5,93,17,3,9,82,28,166,43,69,336,44,18,54,23,103,5,71,379,108,50,282,17,16,185,149,28,98,4,41,314,497,1,151,138,31,116,252,256,104,51,20,129,114,228,35,5,6,20,35,5,378,166,155,44,111,279,132,11,26,21,7,88,3,195,81,8,379,24,112,337,23,6,80,184,7,86,1,40,428,191,4,44,24,23,898,17,24,45,382,44,704,86,141,61,27,300,81,7,89,27,138,8,45,63,30,35,537,13,58,297,54,34,181,57,56,14,2,24,62,26,79,1,60,64,157,110,70],"type":"bar"},{"x":["algorithm","convergence","applications","penalization","reg ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4620,), (4620, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8041666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Gated</span> <span style='background-color:rgba(0, 255, 0, 0.37142857142857155);'>Attention</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Architectures</span> <span style=''>for</span> <span style=''>Task</span> <span style=''>Oriented</span> <span style=''>Language</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Grounding</span> <br/><br/><span style=''>To</span> <span style=''>perform</span> <span style=''>tasks</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specified</span> <span style=''>by</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>instructions</span> <span style='background-color:rgba(0, 255, 0, 0.696969696969697);'>autonomous</span> <span style=''>agents</span> <span style=''>need</span> <span style=''>to</span> <span style=''>extract</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>semantically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>meaningful</span> <span style='background-color:rgba(0, 255, 0, 0.39506172839506176);'>representations</span> <span style=''>of</span> <span style=''>language</span> <span style=''>and</span> <span style=''>map</span> <span style=''>it</span> <span style=''>to</span> <span style=''>visual</span> <span style=''>elements</span> <span style=''>and</span> <span style=''>actions</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6100628930817611);'>environment</span> <span style=''>This</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>called</span> <span style=''>task</span> <span style=''>oriented</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>grounding</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>trainable</span> <span style=''>neural</span> <span style='background-color:rgba(0, 255, 0, 0.4917491749174918);'>architecture</span> <span style=''>for</span> <span style=''>task</span> <span style=''>oriented</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>grounding</span> <span style=''>in</span> <span style=''>3D</span> <span style='background-color:rgba(0, 255, 0, 0.49532710280373843);'>environments</span> <span style=''>which</span> <span style=''>assumes</span> <span style=''>no</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.9240506329113924);'>linguistic</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.9333333333333332);'>perceptual</span> <span style='background-color:rgba(0, 255, 0, 0.42481203007518803);'>knowledge</span> <span style=''>and</span> <span style=''>requires</span> <span style=''>only</span> <span style=''>raw</span> <span style=''>pixels</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6100628930817611);'>environment</span> <span style=''>and</span> <span style=''>the</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>instruction</span> <span style=''>as</span> <span style=''>input</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>model</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>image</span> <span style=''>and</span> <span style=''>text</span> <span style='background-color:rgba(0, 255, 0, 0.39506172839506176);'>representations</span> <span style=''>using</span> <span style=''>a</span> <span style=''>Gated</span> <span style='background-color:rgba(0, 255, 0, 0.37142857142857155);'>Attention</span> <span style='background-color:rgba(0, 255, 0, 0.372093023255814);'>mechanism</span> <span style=''>and</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style=''>PCA</span> <span style=''>for</span> <span style=''>Time</span> <span style=''>Varying</span> <span style=''>Data</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>an</span> <span style=''>online</span> <span style=''>adaptive</span> <span style=''>PCA</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>the</span> <span style=''>full</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigenspace</span> <span style=''>per</span> <span style=''>new</span> <span style=''>time</span> <span style=''>step</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>data</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>one</span> <span style=''>step</span> <span style=''>update</span> <span style=''>rule</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considers</span> <span style=''>all</span> <span style=''>second</span> <span style=''>order</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style=''>previous</span> <span style=''>samples</span> <span style=''>and</span> <span style=''>the</span> <span style=''>new</span> <span style=''>time</span> <span style=''>step</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>has</span> <span style=''>O(n)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>per</span> <span style=''>new</span> <span style=''>time</span> <span style=''>step</span> <span style=''>in</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deterministic</span> <span style=''>mode</span> <span style=''>and</span> <span style=''>O(1)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>per</span> <span style=''>new</span> <span style=''>time</span> <span style=''>step</span> <span style=''>in</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>mode</span> <span style=''>We</span> <span style=''>test</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>on</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>time</span> <span style=''>varying</span> <span style=''>datasets</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>physical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>phenomena</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Explained</span> <span style=''>variance</span> <span style=''>curves</span> <span style=''>indicate</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>provides</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>excellent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>to</span> <span style=''>the</span> <span style=''>original</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigenspace</span> <span style=''>computed</span> <span style=''>using</span> <span style=''>standard</span> <span style=''>PCA</span> <span style=''>in</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Negative</span> <span style=''>Mixture</span> <span style=''>Models</span> <span style=''>by</span> <span style=''>Tensor</span> <span style='background-color:rgba(255, 0, 0, 0.30434782608695654);'>Decompositions</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considers</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.42268041237113396);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>negative</span> <span style=''>mixture</span> <span style=''>models</span> <span style=''>ie</span> <span style=''>mixture</span> <span style=''>models</span> <span style=''>that</span> <span style=''>possibly</span> <span style=''>involve</span> <span style=''>negative</span> <span style=''>weights</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contributions</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>are</span> <span style=''>as</span> <span style=''>follows</span> <span style=''>(i)</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>every</span> <span style=''>rational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>on</span> <span style=''>strings</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3851992409867173);'>representation</span> <span style=''>which</span> <span style=''>occurs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style=''>in</span> <span style=''>spectral</span> <span style=''>learning</span> <span style=''>can</span> <span style=''>be</span> <span style=''>computed</span> <span style=''>by</span> <span style=''>a</span> <span style=''>negative</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>at</span> <span style=''>most</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>automata</span> <span style=''>(or</span> <span style=''>HMMs)</span> <span style=''>(ii)</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>negative</span> <span style=''>mixture</span> <span style=''>models</span> <span style=''>having</span> <span style=''>a</span> <span style=''>specific</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>their</span> <span style=''>low</span> <span style=''>order</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observable</span> <span style=''>moments</span> <span style=''>Building</span> <span style=''>upon</span> <span style=''>a</span> <span style=''>recent</span> <span style=''>paper</span> <span style=''>on</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.30434782608695654);'>decompositions</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>models</span> <span style=''>we</span> <span style=''>extend</span> <span style=''>this</span> <span style=''>work</span> <span style=''>to</span> <span style=''>the</span> <span style=''>broader</span> <span style=''>setting</span> <span style=''>of</span> <span style=''>tensors</span> <span style=''>having</span> <span style=''>a</span> <span style='background-colo ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reformulation</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style=''>Inverse</span> <span style=''>Problems</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>inverse</span> <span style=''>problems</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>a</span> <span style=''>misfit</span> <span style=''>function</span> <span style=''>Despite</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>appeal</span> <span style=''>such</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>suffers</span> <span style=''>from</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>shortcomings</span> <span style=''>eg</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uniqueness</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>modeling</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>etc</span> <span style=''>The</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formalism</span> <span style=''>to</span> <span style=''>inverse</span> <span style=''>problems</span> <span style=''>avoids</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficulties</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encountered</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>approach</span> <span style=''>albeit</span> <span style=''>at</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increased</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>use</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arguments</span> <span style=''>to</span> <span style=''>cast</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>scheme</span> <span style=''>combines</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>soundness</span> <span style=''>of</span> <span style=''>fully</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style=''>of</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <br ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.05253816116435925)
# 	segmentation (0.06567270145544905)
# 	representation (0.12957046503372383)
# 	experimental (0.1501597444089457)
# 	information (0.2499112531061413)
# 	knowledge (0.13454029108981186)
# 	different (0.2594959176428825)
# 	detection (0.11963081292154774)
# 	convolutional (0.13560525381611643)
# 	recognition (0.13560525381611643)
#
# Some Statistics words are:
# 	algorithm (0.37821482602118)
# 	stochastic (0.13212304589006554)
# 	theoretical (0.1502773575390822)
# 	statistical (0.1507816439737771)
# 	variables (0.1437216338880484)
# 	estimation (0.17700453857791226)
# 	distribution (0.18658598083711547)
# 	dimensional (0.18507312153303077)
# 	inference (0.19768028240040342)
# 	regression (0.1800302571860817)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="dff02022-7b63-49c3-a25f-2c27dc20f8df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dff02022-7b63-49c3-a25f-2c27dc20f8df")) {                    Plotly.newPlot(                        "dff02022-7b63-49c3-a25f-2c27dc20f8df",                        [{"x":["algorithm","convergence","applications","penalization","regularized","distances","aforementioned","stochastic","practical","developed","computational","experiments","transport","algorithms","numerical","potentially","characterize","arbitrary","constraints","specifically","understanding","contained","linearity","heuristically","generalized","minimizes","bandwidth","significant","convolutional","rigorously","complexity","extraction","parameters","exponential","therefore","reduction","scattering","operating","prototype","guarantee","determine","convolutions","platforms","symmetries","capabilities","instances","representation","molecules","consistent","specified","infectious","particular","framework","distribution","functions","compactly","applicable","literature","variables","mathematical","essential","conditioned","extension","multivariate","distributions","attributes","structures","relational","including","associated","factorizations","graphical","invariances","represented","projections","independencies","undirected","fundamental","independence","furthermore","projection","assumptions","structure","complicated","projected","optimized","sophisticated","reconstruction","integrity","background","knowledge","sequences","incorporating","outperforms","foreground","reconstructed","segmentation","difficult","reconstruct","simultaneously","competitively","approximately","introduce","classification","pseudolikelihood","resulting","recurrent","interpreted","procedure","prediction","technique","approximate","variational","boltzmann","generative","approximation","inference","addressed","correcting","massively","competing","combinations","explosion","efficient","statistical","selection","combinatorial","continuous","significantly","combination","multiplicative","candidates","statistically","binarization","precision","pyramidal","dimensional","limitations","learnable","techniques","refinement","automated","detection","concerning","laborious","detecting","automatic","neurological","scenarios","encephalography","classifying","approaches","traditional","inspection","consuming","augmentation","university","performance","bottleneck","considerably","regarding","recognition","consisting","information","predictions","comparison","appearance","unfortunately","processing","advantages","crowdsourced","transform","thousands","classifier","positioning","recognize","extracting","published","integrate","demonstrate","accelerated","localization","available","predicted","maintaining","automatically","assumption","probabilities","similarly","blockmodels","approximated","statistics","gradients","appropriate","minibatches","constructed","construction","probabilistic","parameter","comparing","describes","empirical","environments","baselines","algorithmic","automating","processes","experience","productivity","embeddings","transactions","autoencoders","inefficient","marginalized","representations","machinery","experimental","behaviors","systematic","represent","scientists","designing","profiling","targeting","denoising","engineering","maximization","submodular","analyzing","heuristics","theoretical","eigenvalue","selecting","correlated","predictor","guarantees","understand","strongest","complemented","submodularity","applicability","previously","dictionary","covariance","synthetic","excellent","regression","boundaries","procedures","substantial","principle","predictors","consistency","connection","randomi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	marginalized
# 	symmetrization
# 	reversing
# 	regularizations
# 	stationarities
# 	trainability
# 	jacobians
# 	universality
# 	trilinear
# 	announced
# 	repulsion
# 	certificate
# 	forecasted
# 	barycenters
# 	misspecification
# 	periodicity
# 	cytometry
# 	quantiles
# 	covariates
# 	macroeconomic
# Some words which never appear in Statistics papers:
# 	integrity
# 	pyramidal
# 	coherency
# 	abstractive
# 	accuracyspeed
# 	polytrees
# 	attributions
# 	disambiguation
# 	photographs
# 	elevations
# 	stepsizes
# 	experimenting
# 	compilation
# 	publishers
# 	impressions
# 	exposures
# 	psychological
# 	multilayerperception
# 	affective
# 	productive

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0497102775236353e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7491666666666666
